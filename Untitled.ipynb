# %% [markdown]
# # 실습
# ![image.png](attachment:image.png)
# ## ubuntu 환경에서 사설 네트워크를 실행한 후 ipc를 통해 인터페이스로 통신한다.

# %% [markdown]
# ![image.png](attachment:image.png)
# ## 최신 버전이라서 기원 블록 JSON파일의 조건이 복잡한지 전혀 채굴을 못하는 모습이다.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ## 솔리디티로 Remix IDE를 활용해 만든  web3개체를 네트워크에 배치하려 했으나 --rpc 방식을 지원하지 않아 계정을 풀지 못해서 배치하지 못하는 모습이다.
